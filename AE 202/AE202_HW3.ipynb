# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
z = 30000  #ft
v = 500    #ft/s
w = 19815  #lbf
b = 53.3   #ft
SMC = 6*b  #ft
e = 0.81
Cd0 = 0.02
Te = 3650  #lbf

AR = b**2/SMC

Cl = np.linspace(0, 5)

Cd = Cd0 + (Cl**2)/(np.pi * e * AR)

# %%
# 3a

plt.plot(Cd, Cl, 'm-')

plt.title('Drag Polar vs Lift Coefficient')
plt.xlabel('Drag Polar (Cd)')
plt.ylabel('Lift Coefficient (Cl)')
# Out:
# Text(0, 0.5, 'Lift Coefficient (Cl)')

# %%
# 2a - 0 deg AOA

xc_upper_1 = np.array([0.00001,0.00006,0.00034,0.00084,0.00159,0.00258,0.00381,0.0053,0.00704,0.00906,0.01138,0.01404,0.01707,0.02055,0.02453,0.02912,0.03441,0.04054,0.04762,0.05576,0.06501,0.07535,0.0867,0.09891,0.11181,0.12527,0.13916,0.15338,0.16788,0.18258,0.19747,0.21251,0.22767,0.24295,0.25833,0.27379,0.28933,0.30494,0.32061,0.33634,0.35212,0.36796,0.38386,0.39984,0.41594,0.43213,0.44836,0.46464,0.48094,0.49726,0.5136,0.52996,0.54633,0.56271,0.57911,0.59551,0.61192,0.62833,0.64475,0.66117,0.67759,0.69401,0.71043,0.72685,0.74326,0.75967,0.77607,0.79246,0.80884,0.82521,0.84156,0.85789,0.8742,0.89046,0.90663,0.92265,0.93838,0.95357,0.96782,0.98067,0.9918,1])
Cp_upper_1 = np.array([0.99795,0.98921,0.93736,0.84986,0.7389,0.61699,0.49415,0.37677,0.26821,0.16967,0.08107,0.0017,-0.06944,-0.13336,-0.19104,-0.24332,-0.29088,-0.33421,-0.37365,-0.40933,-0.44127,-0.4694,-0.49371,-0.51429,-0.53134,-0.54516,-0.55605,-0.56432,-0.57025,-0.5741,-0.57607,-0.57635,-0.57508,-0.5724,-0.56842,-0.56323,-0.55689,-0.54948,-0.54101,-0.5315,-0.52092,-0.50912,-0.49606,-0.4793,-0.4618,-0.44783,-0.43424,-0.42113,-0.40828,-0.39559,-0.38303,-0.37053,-0.35807,-0.34563,-0.33318,-0.32069,-0.30814,-0.29551,-0.28277,-0.26989,-0.25685,-0.2436,-0.23011,-0.21633,-0.20221,-0.18769,-0.1727,-0.15715,-0.14095,-0.12398,-0.10608,-0.08706,-0.06669,-0.04464,-0.0205,0.0063,0.0365,0.07118,0.11166,0.16244,0.22158,0.41186])
xc_lower_1 = np.array([0.00016,0.00056,0.00122,0.00215,0.00334,0.0048,0.00653,0.00853,0.01081,0.01339,0.01631,0.0196,0.02333,0.02758,0.03242,0.03799,0.04441,0.05182,0.06037,0.07015,0.08116,0.09331,0.10646,0.1204,0.13494,0.14996,0.16532,0.18095,0.1968,0.21282,0.22899,0.24528,0.26168,0.27817,0.29474,0.31139,0.3281,0.34486,0.36167,0.37851,0.39536,0.41215,0.4289,0.44566,0.46244,0.47923,0.49605,0.51289,0.52976,0.54664,0.56354,0.58046,0.5974,0.61435,0.63131,0.64828,0.66527,0.68226,0.69926,0.71626,0.73327,0.75028,0.7673,0.78431,0.80132,0.81833,0.83534,0.85233,0.86931,0.88624,0.90311,0.91982,0.93623,0.95206,0.96689,0.98019,0.99163,1])
Cp_lower_2 = np.array([0.03035,0.33424,0.59405,0.7899,0.91651,0.98186,1,0.9852,0.94918,0.90042,0.84469,0.78574,0.7259,0.66665,0.60887,0.55314,0.49994,0.44968,0.40289,0.36012,0.3219,0.28854,0.26008,0.23622,0.21647,0.20025,0.18698,0.17617,0.16736,0.16021,0.1544,0.14968,0.14585,0.1427,0.14009,0.13787,0.13591,0.13405,0.13214,0.13001,0.12667,0.12184,0.11986,0.11856,0.11786,0.11757,0.11759,0.11787,0.11835,0.119,0.11979,0.1207,0.12171,0.12282,0.124,0.12526,0.12659,0.12801,0.12951,0.1311,0.13281,0.13466,0.13667,0.13888,0.14134,0.14411,0.14728,0.15094,0.15525,0.16041,0.1667,0.17452,0.1845,0.19758,0.21519,0.24081,0.27598,0.41989])

plt.plot(xc_upper_2, Cp_upper_2, 'r-', label='upper')
plt.plot(xc_lower_2, Cp_lower_2, 'b-', label='lower')
plt.legend(loc = 1)
plt.gca().invert_yaxis()
plt.title('Cp vs. x/c (5 deg AOA)')
plt.xlabel('x/c')
plt.ylabel('Cp')`
# Out:
# Text(0, 0.5, 'Cp')

# %%
# 2a - -5 deg AOA

xc_upper_3 = np.array([0.00001,0.00006,0.00034,0.00084,0.00159,0.00258,0.00381,0.0053,0.00704,0.00906,0.01138,0.01404,0.01707,0.02055,0.02453,0.02912,0.03441,0.04054,0.04762,0.05576,0.06501,0.07535,0.0867,0.09891,0.11181,0.12527,0.13916,0.15338,0.16788,0.18258,0.19747,0.21251,0.22767,0.24295,0.25833,0.27379,0.28933,0.30494,0.32061,0.33634,0.35212,0.36796,0.38386,0.39984,0.41594,0.43213,0.44836,0.46464,0.48094,0.49726,0.5136,0.52996,0.54633,0.56271,0.57911,0.59551,0.61192,0.62833,0.64475,0.66117,0.67759,0.69401,0.71043,0.72685,0.74326,0.75967,0.77607,0.79246,0.80884,0.82521,0.84156,0.85789,0.8742,0.89046,0.90663,0.92265,0.93838,0.95357,0.96782,0.98067,0.9918,1])
Cp_upper_3 = np.array([-0.50004,-0.12596,0.21169,0.49369,0.70856,0.85685,0.94699,0.99069,0.99946,0.98301,0.94883,0.90241,0.84766,0.78728,0.72313,0.65653,0.58842,0.51964,0.45099,0.38342,0.31802,0.25589,0.19801,0.14502,0.09718,0.05439,0.01637,-0.01727,-0.04695,-0.07306,-0.09595,-0.11595,-0.13332,-0.14832,-0.16113,-0.17194,-0.1809,-0.18812,-0.1937,-0.1977,-0.20016,-0.201,-0.20024,-0.19592,-0.19047,-0.18737,-0.18416,-0.18092,-0.17752,-0.1739,-0.17007,-0.16599,-0.16167,-0.15711,-0.15229,-0.14722,-0.1419,-0.13631,-0.13044,-0.12428,-0.11782,-0.11102,-0.10388,-0.09635,-0.08839,-0.07996,-0.07101,-0.06146,-0.05123,-0.04022,-0.02829,-0.01527,-0.00096,0.01495,0.03284,0.05323,0.07687,0.1048,0.13842,0.18199,0.23448,0.41276])
xc_lower_3 = np.array([0.00016,0.00056,0.00122,0.00215,0.00334,0.0048,0.00653,0.00853,0.01081,0.01339,0.01631,0.0196,0.02333,0.02758,0.03242,0.03799,0.04441,0.05182,0.06037,0.07015,0.08116,0.09331,0.10646,0.1204,0.13494,0.14996,0.16532,0.18095,0.1968,0.21282,0.22899,0.24528,0.26168,0.27817,0.29474,0.31139,0.3281,0.34486,0.36167,0.37851,0.39536,0.41215,0.4289,0.44566,0.46244,0.47923,0.49605,0.51289,0.52976,0.54664,0.56354,0.58046,0.5974,0.61435,0.63131,0.64828,0.66527,0.68226,0.69926,0.71626,0.73327,0.75028,0.7673,0.78431,0.80132,0.81833,0.83534,0.85233,0.86931,0.88624,0.90311,0.91982,0.93623,0.95206,0.96689,0.98019,0.99163,1])
Cp_lower_3 = np.array([-0.91224,-1.32974,-1.7024,-1.9946,-2.19183,-2.30046,-2.33776,-2.3231,-2.27315,-2.20048,-2.11389,-2.01923,-1.92025,-1.8193,-1.71784,-1.61681,-1.51681,-1.41851,-1.32267,-1.23034,-1.14268,-1.06076,-0.98526,-0.91636,-0.8538,-0.79705,-0.74547,-0.69842,-0.65534,-0.61574,-0.5792,-0.54539,-0.51401,-0.48484,-0.4577,-0.43245,-0.40899,-0.38727,-0.36733,-0.3492,-0.33423,-0.32262,-0.30771,-0.29271,-0.27767,-0.2628,-0.24817,-0.23383,-0.21978,-0.20603,-0.19259,-0.17943,-0.16654,-0.15391,-0.14152,-0.12934,-0.11734,-0.1055,-0.09377,-0.08213,-0.07052,-0.05889,-0.04719,-0.03534,-0.02327,-0.01088,0.00197,0.01542,0.02968,0.04501,0.06178,0.08047,0.10178,0.12672,0.15668,0.19563,0.24331,0.41276])

plt.plot(xc_upper_3, Cp_upper_3, 'r-', label='upper')
plt.plot(xc_lower_3, Cp_lower_3, 'b-', label='lower')
plt.legend(loc = 1)
plt.gca().invert_yaxis()
plt.title('Cp vs. x/c (-5 deg AOA)')
plt.xlabel('x/c')
plt.ylabel('Cp')
# Out:
# Text(0, 0.5, 'Cp')

# %%
# 2b - 0 deg AOA

from sympy import *

Cl1 = 0

for i in range(0, len(Cp_lower_1) - 1):
    Cl1 += Cp_lower_1[i] * (xc_lower_1[i + 1] - xc_lower_1[i])

for i in range(0, len(Cp_upper_1) - 1):
    Cl1 -= Cp_upper_1[i] * (xc_upper_1[i + 1] - xc_upper_1[i])
    
Cl1
# Out:
# 0.2554667463000001

# %%
# 2b - 5 deg AOA

from sympy import *

Cl2 = 0

for i in range(0, len(Cp_lower_2) - 1):
    Cl2 += Cp_lower_2[i] * (xc_lower_2[i + 1] - xc_lower_2[i])

for i in range(0, len(Cp_upper_2) - 1):
    Cl2 -= Cp_upper_2[i] * (xc_upper_2[i + 1] - xc_upper_2[i])
    
Cl2
# Out:
# 0.8695333674000002

# %%
# 2b - -5 deg AOA

from sympy import *

Cl3 = 0

for i in range(0, len(Cp_lower_3) - 1):
    Cl3 += Cp_lower_3[i] * (xc_lower_3[i + 1] - xc_lower_3[i])

for i in range(0, len(Cp_upper_3) - 1):
    Cl3 -= Cp_upper_3[i] * (xc_upper_3[i + 1] - xc_upper_3[i])
    
Cl3
# Out:
# -0.36246345190000023

# %%
# 2c

AOA = np.array([-5, 0, 5])
Cl = np.array([Cl1, Cl2, Cl3])

plt.plot(AOA, Cl)
plt.title('Cl vs. Angle of Attack')
plt.xlabel('Angle of Attack (in degrees)')
plt.ylabel('Cl')
# Out:
# Text(0, 0.5, 'Cl')

# %%
# 2c

slope = (Cl3 - Cl2)/(5 - 0)

Zero_lift_AOA = -Cl2/slope

Zero_lift_AOA
# Out:
# 3.5289594655530614
